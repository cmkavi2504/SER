# %%
# !pip install librosa

# %%
import librosa
from librosa import display

data, sampling_rate = librosa.load('C:/Users/KAVINA/OneDrive/Desktop/Speech Emotion Classification/Audio_Song_Actors_01-24/Actor_04/03-02-06-02-02-02-04.wav')

# %%
import wave
import numpy as np
import matplotlib.pyplot as plt

def plot_wav(file_path):
    # Open the WAV file
    with wave.open(file_path, 'rb') as wave_file:
        # Get the number of frames, framerate, and audio data
        num_frames = wave_file.getnframes()
        framerate = wave_file.getframerate()
        audio_data = np.frombuffer(wave_file.readframes(num_frames), dtype=np.int16)

        # Calculate time values for x-axis
        time_values = np.arange(0, num_frames) / framerate

        # Plot the waveform
        plt.figure(figsize=(10, 4))
        plt.plot(time_values, audio_data, color='blue')
        plt.title('Waveform of {}'.format(file_path))
        plt.xlabel('Time (seconds)')
        plt.ylabel('Amplitude')
        plt.grid(True)
        plt.show()

# Example usage
wav_file_path = 'C:/Users/KAVINA/OneDrive/Desktop/Speech Emotion Classification/Audio_Song_Actors_01-24/Actor_04/03-02-06-02-02-02-04.wav'
plot_wav(wav_file_path)

# %%
import wave
import numpy as np
import matplotlib.pyplot as plt

def plot_spectrogram(file_path):
    # Open the WAV file
    with wave.open(file_path, 'rb') as wave_file:
        # Get the audio data and framerate
        audio_data = np.frombuffer(wave_file.readframes(-1), dtype=np.int16)
        framerate = wave_file.getframerate()

        # Plot the spectrogram
        plt.figure(figsize=(10, 4))
        plt.specgram(audio_data, Fs=framerate)
        plt.title('Spectrogram of {}'.format(file_path))
        plt.xlabel('Time (seconds)')
        plt.ylabel('Frequency (Hz)')
        plt.colorbar(label='Intensity (dB)')
        plt.show()

# Example usage
wav_file_path = 'C:/Users/KAVINA/OneDrive/Desktop/Speech Emotion Classification/Audio_Song_Actors_01-24/Actor_04/03-02-06-02-02-02-04.wav'
plot_spectrogram(wav_file_path)
# Out:
# C:\Users\KAVINA\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:7774: RuntimeWarning: divide by zero encountered in log10
#   Z = 10. * np.log10(spec)

# %%
import wave
import numpy as np
import matplotlib.pyplot as plt

def plot_wav(file_path):
    # Open the WAV file
    with wave.open(file_path, 'rb') as wave_file:
        # Get the number of frames, framerate, and audio data
        num_frames = wave_file.getnframes()
        framerate = wave_file.getframerate()
        audio_data = np.frombuffer(wave_file.readframes(num_frames), dtype=np.int16)

        # Calculate time values for x-axis
        time_values = np.arange(0, num_frames) / framerate

        # Plot the waveform
        plt.figure(figsize=(10, 4))
        plt.plot(time_values, audio_data, color='blue')
        plt.title('Waveform of {}'.format(file_path))
        plt.xlabel('Time (seconds)')
        plt.ylabel('Amplitude')
        plt.grid(True)
        plt.show()

# Example usage
wav_file_path = 'C:/Users/KAVINA/OneDrive/Desktop/Speech Emotion Classification/Audio_Song_Actors_01-24/Actor_04/03-02-01-01-01-02-04.wav'
plot_wav(wav_file_path)

# %%
import wave
import numpy as np
import matplotlib.pyplot as plt

def plot_spectrogram(file_path):
    # Open the WAV file
    with wave.open(file_path, 'rb') as wave_file:
        # Get the audio data and framerate
        audio_data = np.frombuffer(wave_file.readframes(-1), dtype=np.int16)
        framerate = wave_file.getframerate()

        # Plot the spectrogram
        plt.figure(figsize=(10, 4))
        plt.specgram(audio_data, Fs=framerate)
        plt.title('Spectrogram of {}'.format(file_path))
        plt.xlabel('Time (seconds)')
        plt.ylabel('Frequency (Hz)')
        plt.colorbar(label='Intensity (dB)')
        plt.show()

# Example usage
wav_file_path = 'C:/Users/KAVINA/OneDrive/Desktop/Speech Emotion Classification/Audio_Song_Actors_01-24/Actor_04/03-02-01-01-01-02-04.wav'
plot_spectrogram(wav_file_path)

# %%
import wave
import numpy as np
import matplotlib.pyplot as plt

def plot_wav(file_path):
    # Open the WAV file
    with wave.open(file_path, 'rb') as wave_file:
        # Get the number of frames, framerate, and audio data
        num_frames = wave_file.getnframes()
        framerate = wave_file.getframerate()
        audio_data = np.frombuffer(wave_file.readframes(num_frames), dtype=np.int16)

        # Calculate time values for x-axis
        time_values = np.arange(0, num_frames) / framerate

        # Plot the waveform
        plt.figure(figsize=(10, 4))
        plt.plot(time_values, audio_data, color='blue')
        plt.title('Waveform of {}'.format(file_path))
        plt.xlabel('Time (seconds)')
        plt.ylabel('Amplitude')
        plt.grid(True)
        plt.show()

# Example usage
wav_file_path = 'C:/Users/KAVINA/OneDrive/Desktop/Speech Emotion Classification/Audio_Song_Actors_01-24/Actor_04/03-02-03-01-02-01-04.wav'
plot_wav(wav_file_path)

# %%
import wave
import numpy as np
import matplotlib.pyplot as plt

def plot_spectrogram(file_path):
    # Open the WAV file
    with wave.open(file_path, 'rb') as wave_file:
        # Get the audio data and framerate
        audio_data = np.frombuffer(wave_file.readframes(-1), dtype=np.int16)
        framerate = wave_file.getframerate()

        # Plot the spectrogram
        plt.figure(figsize=(10, 4))
        plt.specgram(audio_data, Fs=framerate)
        plt.title('Spectrogram of {}'.format(file_path))
        plt.xlabel('Time (seconds)')
        plt.ylabel('Frequency (Hz)')
        plt.colorbar(label='Intensity (dB)')
        plt.show()

# Example usage
wav_file_path = 'C:/Users/KAVINA/OneDrive/Desktop/Speech Emotion Classification/Audio_Song_Actors_01-24/Actor_04/03-02-03-01-02-01-04.wav'
plot_spectrogram(wav_file_path)

# %%
import time
import os
import librosa
import numpy as np

# %%
import IPython
IPython.Application.instance().kernel.do_shutdown(True)
# Out:
# {'status': 'ok', 'restart': True}

# %%
# !pip install resampy

# %%
import time
import os
import librosa
import numpy as np

# Assuming you have already installed the 'resampy' library


path = 'C:/Users/KAVINA/OneDrive/Desktop/Speech Emotion Classification/features/Actor_01'
files = os.listdir(path)
#print(files)

lst = []

start_time = time.time()

for subdir, dirs, files in os.walk(path):
  for file in files:
      try:
        # Load librosa array, obtain mfccs, store the file and the mcss information in a new array
        X, sample_rate = librosa.load(os.path.join(subdir, file), res_type='kaiser_fast')
        mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T, axis=0)
        # The instruction below converts the labels (from 1 to 8) to a series from 0 to 7
        # This is because our predictor needs to start from 0 otherwise it will try to predict also 0.
        label = int(file[7:8]) - 1
        arr = mfccs, label
        lst.append(arr)
      # If the file is not valid, skip it
      except ValueError:
        continue

print("--- Data loaded. Loading time: %s seconds ---" % (time.time() - start_time))
# Out:
# --- Data loaded. Loading time: 585.3484709262848 seconds ---

# %%
# Creating X and y: zip makes a list of all the first elements, and a list of all the second elements.
X, y = zip(*lst)

# %%
import numpy as np
X = np.asarray(X)
y = np.asarray(y)


X.shape, y.shape
# Out:
# ((2452, 40), (2452,))

# %%
# Saving joblib files to not load them again with the loop above

import joblib

X_name = 'X.joblib'
y_name = 'y.joblib'
save_dir = 'C:/Users/KAVINA/OneDrive/Desktop/Speech Emotion Classification/features/'

savedX = joblib.dump(X, os.path.join(save_dir, X_name))
savedy = joblib.dump(y, os.path.join(save_dir, y_name))

# %%
# Loading saved models
import joblib
X = joblib.load('C:/Users/KAVINA/OneDrive/Desktop/Speech Emotion Classification/features/X.joblib')
y = joblib.load('C:/Users/KAVINA/OneDrive/Desktop/Speech Emotion Classification/features/y.joblib')

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.33, random_state=42)

# %%
import numpy as np
x_traincnn = np.expand_dims(X_train, axis=2)
x_testcnn = np.expand_dims(X_test, axis=2)

# %%
x_traincnn.shape, x_testcnn.shape
# Out:
# ((1642, 40, 1), (810, 40, 1))

# %%
import keras
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Embedding
from keras.utils import to_categorical
from keras.layers import Input, Flatten, Dropout, Activation
from keras.layers import Conv1D, MaxPooling1D
from keras.models import Model
from keras.callbacks import ModelCheckpoint

model = Sequential()

model.add(Conv1D(64, 5, padding='same', input_shape=(40, 1)))
model.add(Activation('relu'))
model.add(Dropout(0.1))
model.add(MaxPooling1D(pool_size=(4)))
model.add(Conv1D(128, 5, padding='same'))
model.add(Activation('relu'))
model.add(Dropout(0.1))
model.add(MaxPooling1D(pool_size=(4)))
model.add(Conv1D(256, 5, padding='same'))
model.add(Activation('relu'))
model.add(Dropout(0.1))
model.add(Flatten())
model.add(Dense(8))
model.add(Activation('softmax'))

# Corrected optimizer definition
#opt = keras.optimizers.RMSprop(learning_rate=0.00005, rho=0.9, epsilon=1e-07, decay=0.0)

model.summary()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d (Conv1D)             (None, 40, 64)            384
#
#  activation (Activation)     (None, 40, 64)            0
#
#  dropout (Dropout)           (None, 40, 64)            0
#
#  max_pooling1d (MaxPooling1  (None, 10, 64)            0
#  D)
#
#  conv1d_1 (Conv1D)           (None, 10, 128)           41088
#
#  activation_1 (Activation)   (None, 10, 128)           0
#
#  dropout_1 (Dropout)         (None, 10, 128)           0
#
#  max_pooling1d_1 (MaxPoolin  (None, 2, 128)            0
#  g1D)
#
#  conv1d_2 (Conv1D)           (None, 2, 256)            164096
#
#  activation_2 (Activation)   (None, 2, 256)            0
#
#  dropout_2 (Dropout)         (None, 2, 256)            0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 8)                 4104
#
# ...

# %%
model.compile(loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\KAVINA\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
#cnnhistory=model.fit(x_traincnn, y_train, batch_size=16, epochs=200, validation_data=(x_testcnn, y_test))

# %%
plt.plot(cnnhistory.history['loss'])
plt.plot(cnnhistory.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 plt.plot(cnnhistory.history['loss'])
#       2 plt.plot(cnnhistory.history['val_loss'])
#       3 plt.title('model loss')
#
# NameError: name 'cnnhistory' is not defined

# %%
plt.plot(cnnhistory.history['accuracy'])
plt.plot(cnnhistory.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 plt.plot(cnnhistory.history['accuracy'])
#       2 plt.plot(cnnhistory.history['val_accuracy'])
#       3 plt.title('model accuracy')
#
# NameError: name 'cnnhistory' is not defined

# %%
predictions = model.predict_classes(x_testcnn)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 predictions = model.predict_classes(x_testcnn)
#
# AttributeError: 'Sequential' object has no attribute 'predict_classes'

# %%
predictions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 predictions
#
# NameError: name 'predictions' is not defined

# %%
y_test
# Out:
# array([2, 2, 3, 1, 1, 1, 1, 2, 4, 4, 0, 6, 5, 2, 1, 3, 2, 4, 5, 3, 6, 4,
#        0, 1, 6, 4, 2, 6, 7, 7, 4, 5, 3, 7, 4, 4, 1, 3, 4, 3, 3, 5, 2, 2,
#        7, 4, 5, 3, 6, 3, 1, 4, 6, 3, 1, 4, 5, 0, 5, 2, 1, 3, 5, 3, 1, 3,
#        2, 4, 6, 3, 4, 2, 6, 5, 5, 2, 2, 0, 5, 3, 7, 3, 3, 1, 4, 4, 0, 4,
#        3, 5, 1, 5, 4, 2, 2, 1, 3, 5, 4, 7, 6, 2, 1, 7, 3, 2, 7, 2, 3, 4,
#        7, 4, 4, 5, 1, 1, 0, 1, 7, 1, 2, 1, 6, 0, 2, 2, 3, 2, 2, 3, 5, 0,
#        4, 6, 0, 7, 3, 7, 7, 1, 5, 1, 2, 7, 4, 4, 5, 2, 2, 4, 6, 7, 7, 2,
#        6, 5, 3, 6, 2, 4, 4, 1, 4, 4, 3, 1, 6, 0, 5, 1, 5, 2, 1, 5, 1, 2,
#        1, 7, 2, 2, 6, 1, 2, 2, 1, 1, 1, 4, 7, 1, 3, 3, 5, 3, 0, 5, 1, 0,
#        4, 1, 1, 4, 3, 3, 7, 4, 3, 1, 3, 4, 7, 0, 5, 3, 5, 0, 2, 1, 1, 2,
#        6, 1, 5, 3, 4, 2, 3, 0, 2, 4, 3, 5, 5, 4, 2, 7, 4, 5, 3, 3, 0, 7,
#        1, 5, 3, 0, 4, 3, 3, 3, 2, 5, 2, 4, 2, 4, 3, 2, 3, 0, 3, 4, 5, 3,
#        1, 3, 1, 5, 2, 7, 1, 7, 4, 1, 1, 2, 0, 0, 2, 1, 4, 5, 5, 2, 6, 5,
# ...

# %%
new_Ytest = y_test.astype(int)

# %%
new_Ytest
# Out:
# array([2, 2, 3, 1, 1, 1, 1, 2, 4, 4, 0, 6, 5, 2, 1, 3, 2, 4, 5, 3, 6, 4,
#        0, 1, 6, 4, 2, 6, 7, 7, 4, 5, 3, 7, 4, 4, 1, 3, 4, 3, 3, 5, 2, 2,
#        7, 4, 5, 3, 6, 3, 1, 4, 6, 3, 1, 4, 5, 0, 5, 2, 1, 3, 5, 3, 1, 3,
#        2, 4, 6, 3, 4, 2, 6, 5, 5, 2, 2, 0, 5, 3, 7, 3, 3, 1, 4, 4, 0, 4,
#        3, 5, 1, 5, 4, 2, 2, 1, 3, 5, 4, 7, 6, 2, 1, 7, 3, 2, 7, 2, 3, 4,
#        7, 4, 4, 5, 1, 1, 0, 1, 7, 1, 2, 1, 6, 0, 2, 2, 3, 2, 2, 3, 5, 0,
#        4, 6, 0, 7, 3, 7, 7, 1, 5, 1, 2, 7, 4, 4, 5, 2, 2, 4, 6, 7, 7, 2,
#        6, 5, 3, 6, 2, 4, 4, 1, 4, 4, 3, 1, 6, 0, 5, 1, 5, 2, 1, 5, 1, 2,
#        1, 7, 2, 2, 6, 1, 2, 2, 1, 1, 1, 4, 7, 1, 3, 3, 5, 3, 0, 5, 1, 0,
#        4, 1, 1, 4, 3, 3, 7, 4, 3, 1, 3, 4, 7, 0, 5, 3, 5, 0, 2, 1, 1, 2,
#        6, 1, 5, 3, 4, 2, 3, 0, 2, 4, 3, 5, 5, 4, 2, 7, 4, 5, 3, 3, 0, 7,
#        1, 5, 3, 0, 4, 3, 3, 3, 2, 5, 2, 4, 2, 4, 3, 2, 3, 0, 3, 4, 5, 3,
#        1, 3, 1, 5, 2, 7, 1, 7, 4, 1, 1, 2, 0, 0, 2, 1, 4, 5, 5, 2, 6, 5,
# ...

# %%
from sklearn.metrics import classification_report
report = classification_report(new_Ytest, predictions)
print(report)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 from sklearn.metrics import classification_report
# ----> 2 report = classification_report(new_Ytest, predictions)
#       3 print(report)
#
# NameError: name 'predictions' is not defined

# %%
from sklearn.metrics import confusion_matrix
matrix = confusion_matrix(new_Ytest, predictions)
print (matrix)

# 0 = neutral, 1 = calm, 2 = happy, 3 = sad, 4 = angry, 5 = fearful, 6 = disgust, 7 = surprised
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 from sklearn.metrics import confusion_matrix
# ----> 2 matrix = confusion_matrix(new_Ytest, predictions)
#       3 print (matrix)
#
# NameError: name 'predictions' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

# Confusion matrix data
matrix_data = np.array([[172, 5, 1, 8, 0, 0, 1, 3],
                        [6, 89, 5, 9, 0, 0, 6, 2],
                        [4, 6, 223, 5, 8, 8, 3, 9],
                        [7, 7, 3, 212, 3, 8, 4, 2],
                        [1, 2, 4, 2, 232, 8, 15, 1],
                        [0, 1, 6, 23, 10, 196, 8, 2],
                        [1, 2, 0, 2, 5, 1, 186, 5],
                        [5, 4, 6, 4, 2, 1, 8, 172]])

# Define class labels
class_labels = ['Neutral', 'Calm', 'Happy', 'Sad', 'Angry', 'Fearful', 'Disgust', 'Surprised']

# Create ConfusionMatrixDisplay object and plot
disp = ConfusionMatrixDisplay(confusion_matrix=matrix_data, display_labels=class_labels)
fig, ax = plt.subplots(figsize=(10, 8))  # Adjust the figure size if needed
disp.plot(ax=ax, cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %%
model.save('testing10_model.h5')
print("MODEL SAVED")
# Out:
# C:\Users\KAVINA\anaconda3\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# MODEL SAVED

# %%
new_model=keras.models.load_model('testing10_model.h5')
new_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d (Conv1D)             (None, 40, 64)            384
#
#  activation (Activation)     (None, 40, 64)            0
#
#  dropout (Dropout)           (None, 40, 64)            0
#
#  max_pooling1d (MaxPooling1  (None, 10, 64)            0
#  D)
#
#  conv1d_1 (Conv1D)           (None, 10, 128)           41088
#
#  activation_1 (Activation)   (None, 10, 128)           0
#
#  dropout_1 (Dropout)         (None, 10, 128)           0
#
#  max_pooling1d_1 (MaxPoolin  (None, 2, 128)            0
#  g1D)
#
#  conv1d_2 (Conv1D)           (None, 2, 256)            164096
#
#  activation_2 (Activation)   (None, 2, 256)            0
#
#  dropout_2 (Dropout)         (None, 2, 256)            0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 8)                 4104
#
# ...

# %%
loss, acc = new_model.evaluate(x_testcnn, y_test)
print("Restored model, accuracy: {:5.2f}%".format(100*acc))
# Out:
# WARNING:tensorflow:From C:\Users\KAVINA\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 26/26 [==============================] - 2s 14ms/step - loss: 11.6869 - accuracy: 0.0000e+00
# Restored model, accuracy:  0.00%

# %%
import keras
import numpy as np
import librosa

class livePredictions:
    """
    Main class of the application.
    """

    def __init__(self, path, file):
        """
        Init method is used to initialize the main parameters.
        """
        self.path = path
        self.file = file

    def load_model(self):
        """
        Method to load the chosen model.
        :param path: path to your h5 model.
        :return: summary of the model with the .summary() function.
        """
        self.loaded_model = keras.models.load_model(self.path)
        return self.loaded_model.summary()

    def makepredictions(self):
        """
        Method to process the files and create your features.
        """
        data, sampling_rate = librosa.load(self.file)
        mfccs = np.mean(librosa.feature.mfcc(y=data, sr=sampling_rate, n_mfcc=40).T, axis=0)
        x = np.expand_dims(mfccs, axis=0)
        x = np.expand_dims(x, axis=2)  # Add an extra dimension for compatibility with model input
        predictions = self.loaded_model.predict(x)
        predicted_class = np.argmax(predictions)  # Get the index of the highest probability
        print("Prediction is", self.convertclasstoemotion(predicted_class))

    @staticmethod
    def convertclasstoemotion(pred):
        """
        Method to convert the predictions (int) into human-readable strings.
        """
        label_conversion = {0: 'neutral',
                            1: 'calm',
                            2: 'happy',
                            3: 'sad',
                            4: 'angry',
                            5: 'fearful',
                            6: 'disgust',
                            7: 'surprised'}
        return label_conversion[pred]

pred = livePredictions(path='C:/Users/KAVINA/OneDrive/Desktop/Speech Emotion Classification/Speech-Emotion-Recognition-using-ML-and-DL-master/Deep Learning/SER_model.h5',file='C:/Users/KAVINA/OneDrive/Desktop/Speech Emotion Classification/examples/03-02-05-02-01-02-04.wav')

pred.load_model()
pred.makepredictions()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d_1 (Conv1D)           (None, 40, 64)            384
#
#  activation_1 (Activation)   (None, 40, 64)            0
#
#  dropout_1 (Dropout)         (None, 40, 64)            0
#
#  max_pooling1d_1 (MaxPoolin  (None, 10, 64)            0
#  g1D)
#
#  conv1d_2 (Conv1D)           (None, 10, 128)           41088
#
#  activation_2 (Activation)   (None, 10, 128)           0
#
#  dropout_2 (Dropout)         (None, 10, 128)           0
#
#  max_pooling1d_2 (MaxPoolin  (None, 2, 128)            0
#  g1D)
#
#  conv1d_3 (Conv1D)           (None, 2, 256)            164096
#
#  activation_3 (Activation)   (None, 2, 256)            0
#
#  dropout_3 (Dropout)         (None, 2, 256)            0
#
#  flatten_1 (Flatten)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 8)                 4104
#
# ...

# %%
from flask import Flask, render_template, request, redirect, url_for
import os
import keras
import numpy as np
import librosa

app = Flask(__name__)
app.config['UPLOAD_FOLDER'] = 'static/uploads'

class livePredictions:
    # Your livePredictions class implementation goes here

@app.route('/')
def index():
    return render_template('index.html')

@app.route('/predict', methods=['POST'])
def predict():
    if 'file' not in request.files:
        return redirect(request.url)
    file = request.files['file']
    if file.filename == '':
        return redirect(request.url)
    if file:
        filepath = os.path.join(app.config['UPLOAD_FOLDER'], file.filename)
        file.save(filepath)
        pred = livePredictions(path='path_to_your_model/SER_model.h5', file=filepath)
        pred.load_model()
        prediction = pred.makepredictions()
        return render_template('result.html', prediction=prediction)

if __name__ == '__main__':
    app.run(debug=True)
# Out:
#   Cell In[28], line 13
#     @app.route('/')
#     ^
# IndentationError: expected an indented block after class definition on line 10

# %%
from flask import Flask, render_template, request, redirect, url_for
import os
import keras
import numpy as np
import librosa

app = Flask(__name__)
app.config['UPLOAD_FOLDER'] = 'static/uploads'

class livePredictions:
    """
    Main class for making live predictions using a trained model.
    """

    def __init__(self, path, file):
        """
        Initialize the livePredictions object with model path and file path.
        """
        self.path = path
        self.file = file
        self.loaded_model = None

    def load_model(self):
        """
        Load the trained model using Keras.
        """
        self.loaded_model = keras.models.load_model(self.path)

    def makepredictions(self):
        """
        Process the audio file and make predictions using the loaded model.
        """
        data, sampling_rate = librosa.load(self.file)
        mfccs = np.mean(librosa.feature.mfcc(y=data, sr=sampling_rate, n_mfcc=40).T, axis=0)
        x = np.expand_dims(mfccs, axis=0)
        x = np.expand_dims(x, axis=2)  # Add an extra dimension for compatibility with model input
        predictions = self.loaded_model.predict(x)
        predicted_class = np.argmax(predictions)  # Get the index of the highest probability
        return self.convertclasstoemotion(predicted_class)

    @staticmethod
    def convertclasstoemotion(pred):
        """
        Convert the predicted class index to human-readable emotion labels.
        """
        label_conversion = {0: 'neutral',
                            1: 'calm',
                            2: 'happy',
                            3: 'sad',
                            4: 'angry',
                            5: 'fearful',
                            6: 'disgust',
                            7: 'surprised'}
        return label_conversion[pred]

@app.route('/')
def index():
    """
    Render the index.html template for uploading files.
    """
    return render_template('index.html')

@app.route('/predict', methods=['POST'])
def predict():
    """
    Handle file upload and make predictions.
    """
    if 'file' not in request.files:
        return redirect(request.url)
    file = request.files['file']
    if file.filename == '':
        return redirect(request.url)
    if file:
        filepath = os.path.join(app.config['UPLOAD_FOLDER'], file.filename)
        file.save(filepath)
        pred = livePredictions(path='C:/Users/KAVINA/OneDrive/Desktop/Speech Emotion Classification/Speech-Emotion-Recognition-using-ML-and-DL-master/Deep Learning/SER_model.h5', file=filepath)
        pred.load_model()
        prediction = pred.makepredictions()
        return render_template('result.html', prediction=prediction)

if __name__ == '__main__':
    app.run(host="0.0.0.0", port=8080)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:8080
#  * Running on http://192.168.0.106:8080
# Press CTRL+C to quit
# 192.168.0.106 - - [06/Jun/2024 20:01:47] "GET / HTTP/1.1" 200 -
# 192.168.0.106 - - [06/Jun/2024 20:01:47] "GET /favicon.ico HTTP/1.1" 404 -
# 1/1 [==============================] - 0s 318ms/step
# 192.168.0.106 - - [06/Jun/2024 20:02:08] "POST /predict HTTP/1.1" 200 -
# 192.168.0.106 - - [06/Jun/2024 20:02:20] "GET / HTTP/1.1" 200 -
# 1/1 [==============================] - 0s 315ms/step
# 192.168.0.106 - - [06/Jun/2024 20:02:28] "POST /predict HTTP/1.1" 200 -
